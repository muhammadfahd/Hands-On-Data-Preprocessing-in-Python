# %% [markdown]
# # Data Pre-processing
# We will be doing following steps

# %% [markdown]
# ## loading libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## reading dataset

# %%
dataset=pd.read_csv('population.csv')

# %%
# previewing first rows
dataset.head()
# Out:
#     ReadingDateTime Species  Value
# 0  01/01/2017 00:00      NO    3.5
# 1  01/01/2017 01:00      NO    3.6
# 2  01/01/2017 02:00      NO    2.2
# 3  01/01/2017 00:00     NO2   30.8
# 4  01/01/2017 01:00     NO2   31.5

# %%
# dataset size
dataset.shape
# Out:
# (528, 21)

# %%
# list coloumn names
dataset.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# summary stats 
dataset.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    509.000000       4.800000e+02  4.810000e+02    4.790000e+02
# mean    1509.705501       2.453517e+05  1.245452e+05    1.204401e+05
# std     2066.762124       2.681297e+05  1.359033e+05    1.325276e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      434.000000       5.414175e+04  2.869500e+04    2.470600e+04
# 50%      885.000000       1.677015e+05  8.439000e+04    8.277400e+04
# 75%     1768.000000       3.095348e+05  1.599780e+05    1.515835e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           481.000000         488.000000                  503.000000
# mean             18.014553          99.642295                    6.240875
# std              25.049821          25.952591                    2.095014
# ...

# %%
# finding datatypes
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    521 non-null    object
#  1   DIVISION                    507 non-null    object
#  2   DISTRICT                    507 non-null    object
#  3   SUB DIVISION                510 non-null    object
#  4   AREA (sq.km)                509 non-null    float64
#  5   ALL SEXES (RURAL)           480 non-null    float64
#  6   MALE (RURAL)                481 non-null    float64
#  7   FEMALE (RURAL)              479 non-null    float64
#  8   TRANSGENDER (RURAL)         481 non-null    float64
#  9   SEX RATIO (RURAL)           488 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  503 non-null    float64
#  11  POPULATION 1998 (RURAL)     521 non-null    float64
#  12  ANNUAL GROWTH RATE (RURAL)  523 non-null    float64
# ...

# %%
# viewing particualar coloumn
dataset['AREA (sq.km)']
# Out:
# 0      1729.0
# 1      1500.0
# 2      2536.0
# 3      1295.0
# 4      1818.0
#         ...
# 523     813.0
# 524     398.0
# 525     734.0
# 526     567.0
# 527    2315.0
# Name: AREA (sq.km), Length: 528, dtype: float64

# %%
# accessding specific range
dataset.loc[10:50 ,'AREA (sq.km)']
# Out:
# 10    18374.0
# 11     3190.0
# 12     3262.0
# 13     2464.0
# 14     2964.0
# 15     5339.0
# 16     2012.0
# 17     1802.0
# 18     2769.0
# 19     2754.0
# 20     1712.0
# 21     1391.0
# 22     1010.0
# 23     3471.0
# 24     2377.0
# 25     5013.0
# 26     2322.0
# 27     2078.0
# 28     2905.0
# 29      879.0
# 30      709.0
# 31     1055.0
# 32      654.0
# 33      168.0
# 34     1186.0
# 35     1811.0
# 36      754.0
# 37     1284.0
# 38     1566.0
# 39      851.0
# 40     2591.0
# 41     1158.0
# 42      851.0
# 43      486.0
# 44      774.0
# 45     1141.0
# 46      131.0
# 47      783.0
# 48      834.0
# 49      678.0
# 50     1196.0
# Name: AREA (sq.km), dtype: float64

# %%
# basic visualization
dataset['AREA (sq.km)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset['AVG HOUSEHOLD SIZE (RURAL)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
